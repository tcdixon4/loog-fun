# %%
# from requests import get
# from requests.exceptions import RequestException
# from contextlib import closing
import numpy as np
import pandas as pd
import re
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from sqlalchemy import create_engine
import sqlite3

# %%
def espn_login(driver=None):  # Likely return to this to put it in another file
    '''If there is no active WebDriver session, open one and request ESPN 
    login.  Wait until login has been registered before advancing.
    Args:
        driver: selenium WebDriver instance, logged in OR out of ESPN
    Return:
        driver: selenium WebDriver instance, logged in to ESPN

    '''
    if not driver:
        driver = webdriver.Chrome('C:\ChromeDriver\chromedriver.exe')
    driver.get('http://www.espn.com/login/')
    logged_in = False
    while not logged_in:
        innerHTML = driver.execute_script(
            "return document.getElementsByTagName('html')[0].innerHTML")
        html = BeautifulSoup(innerHTML, 'html.parser')
        logged_in = not html.find_all('title')[0].get_text()=='Log In'
    return driver

# %%
driver = espn_login()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-047007f2ae81> in <module>()
# ----> 1 driver = espn_login()
#
# <ipython-input-2-bdc596b5442d> in espn_login(driver)
#      15         innerHTML = driver.execute_script(
#      16             "return document.getElementsByTagName('html')[0].innerHTML")
# ---> 17         html = BeautifulSoup(innerHTML, 'html.parser')
#      18         logged_in = not html.find_all('title')[0].get_text()=='Log In'
#      19     return driver
#
# C:\Users\Tanner\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     190         if hasattr(markup, 'read'):        # It's a file-type object.
#     191             markup = markup.read()
# --> 192         elif len(markup) <= 256 and (
#     193                 (isinstance(markup, bytes) and not b'<' in markup)
#     194                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'NoneType' has no len()

# %%
def update_player_df(driver=None):
    ''' This function creates a pandas DataFrame where each row represents
    a single player with fields {name, pos, team, owner, keeper_val}.  It is
    meant to be run once per off-season, after the full player list for the
    upcoming draft has been updated on ESPN.  The field keeper_val initializes
    to NaN for all players, and must be modified manually or using the
    update_keeper_val function from this module afterwards.
    Args:
        driver: selenium WebDriver instance (optional), logged in OR out of ESPN
    Return:
        player_df: pandas DataFrame (n x 5) containing updated list of players 
                   for upcoming draft, but incomplete keeper_val field
    '''

    driver = espn_login(driver)
    driver.implicitly_wait(5)

    ''' Initialize an empty DataFrame, navigate to the player page, and begin to
    fill it.  Players will be added to the larger player_df DataFrame in chunks,
    with each chunk containing all the players on a single page. 
    '''
    player_df = pd.DataFrame(columns=['name', 'pos', 'team', 'owner', 
                                      'keeper_val'])
    driver.get('http://games.espn.com/ffl/freeagency?leagueId=2205911&teamId='
               '6&seasonId=2017#&seasonId=2017&avail=-1')
    last_player_logged = []
    while True:
        ''' Check to see if the page has loaded by testing if the last player
        on the page is the same as the last one logged on the previous page.
        '''
        waiting_to_load = True
        while waiting_to_load:          
            innerHTML = driver.execute_script(
                "return document.getElementsByTagName('html')[0].innerHTML")
            html = BeautifulSoup(innerHTML, 'html.parser')
            player_table = html.find(id='playertable_0')
            last_player_loaded = player_table.find_all('tr')[-1]
            last_player_loaded = last_player_loaded.find_all('td')[0].get_text()
            if last_player_logged != last_player_loaded:
                waiting_to_load = False

        ''' Fill the df_chunk DataFrame for the current page by iterating over
        every row and parsing the player data.
        '''
        players_on_page = len(player_table.find_all('tr'))-2   
        df_chunk = pd.DataFrame(
            columns=['name', 'team', 'pos', 'owner', 'keeper_val'], 
            index=range(0,players_on_page))
        row_marker = -1
        for row in player_table.find_all('tr')[2:]:
            row_marker += 1
            last_player_logged = row.find_all('td')[0].get_text()
            name_team_pos = re.split(', |\xa0', last_player_logged)
            if len(name_team_pos)==2:  # This applies only to d/st entries
                team_name = re.split(' ', name_team_pos[0])[0]
                name_team_pos = [name_team_pos[0], team_name, name_team_pos[1]]
            df_chunk.iat[row_marker, 0] = name_team_pos[0]
            df_chunk.iat[row_marker, 1] = name_team_pos[1]
            df_chunk.iat[row_marker, 2] = name_team_pos[2]
            df_chunk.iat[row_marker, 3] = row.find_all('td')[2].get_text()  
        player_df = player_df.append(df_chunk)
        ''' If another page becomes available within 3 seconds, click it to
        advance.  Otherwise, assume the final page has been reached, complete 
        the process, and exit the while loop.
        '''
        try:
            remaining_page = WebDriverWait(driver, 3).until(
            	EC.element_to_be_clickable((By.PARTIAL_LINK_TEXT, 'NEXT')))
            remaining_page.click()
        except:
            print('scraping complete')
            break

    ''' Fix the indices on the player_df DataFrame to match the number of the
    row, since each chunk was originally indexed separately.  Finally, return 
    the result.
    '''
    player_df = player_df.set_index(np.arange(len(player_df)))
    return(player_df)

# %%
driver = espn_login(driver)
driver.implicitly_wait(5)

''' Initialize an empty DataFrame, navigate to the player page, and begin to
fill it.  Players will be added to the larger player_df DataFrame in chunks,
with each chunk containing all the players on a single page. 
'''
player_df = pd.DataFrame(columns=['name', 'pos', 'team', 'owner', 
                                  'keeper_val'])

# %%
driver = webdriver.Chrome('C:\ChromeDriver\chromedriver.exe')

# %%
driver.get('http://www.espn.com/login/')

# %%
elem = driver.find_element_by_css_selector('div')

# %%
elem
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3833d56f889b84070804310f51092e67", element="0.6787683700728167-1")>

# %%
def update_keeper_val(driver=None, prev_player_df=None, player_df=None):
    ''' This function updates the keeper_val field for all players of a 
    player_df DataFrame that has recently been created using the 
    update_player_df function.
    Args:
        driver: selenium WebDriver instance (optional), logged in OR out of ESPN
        prev_player_df: pandas DataFrame containing previous season's keeper_val
                        data
        player_df: pandas DataFrame containing updated list of players for
                   upcoming draft, but incomplete keeper_val field
    Returns:
        player_df: pandas DataFrame containing updated list of players for
                   upcoming draft, with complete keeper_val field
    '''
    
    if not driver:
        driver = espn_login(driver)
        driver.implicitly_wait(5)

    '''Navigate to the transactions page and change the date range to include 
    the full transaction history.
    '''
    driver.get('http://games.espn.com/ffl/recentactivity?leagueId=2205911&'
               'activityType=2')
    innerHTML = driver.execute_script(
        "return document.getElementsByTagName('html')[0].innerHTML")
    html = BeautifulSoup(innerHTML, 'html.parser')
    ''' Log the oldest transaction on the page so that you can check whether the
    form submission for including full transactions has finished loading.
    '''
    check_element_prev = html.find_all('tr')[-1].get_text()
    check_element_cur = check_element_prev
    startDate = Select(driver.find_element_by_name('startDate'))
    startDate.select_by_index(0)
    driver.find_element_by_name('startDate').submit()
    while check_element_prev == check_element_cur:
        innerHTML = driver.execute_script(
            "return document.getElementsByTagName('html')[0].innerHTML")
        html = BeautifulSoup(innerHTML, 'html.parser')
        check_element_prev = html.find_all('tr')[-1].get_text()

    ''' Iterate over all of the currently owned players and assign 7 as their
    keeper value if they were a FA pickup.
    '''
    owned_players = player_df.loc[player_df['owner'] != 'FA']
    for ind, player in owned_players.iterrows():
        try:
            trans_index = 0
            while True:
                trans_text = html(text=player['name']
                    )[trans_index].find_parents('td')[0].get_text()
                if 'added' in trans_text:
                    player_df.loc[ind]['keeper_val'] = 7
                    break
                else:
                    trans_index += 1
        except IndexError:
            pass
    print(player_df)

    ''' Iterate over all of the remaining owned players, which must have
    been drafted, and assign their keeper values based on the round they
    were drafted in.  Also, reduce their value by 1 if they were kept last
    season.
    '''
    driver.get(
        'http://games.espn.com/ffl/tools/draftrecap?leagueId=2205911')
    innerHTML = driver.execute_script(
        "return document.getElementsByTagName('html')[0].innerHTML")
    html = BeautifulSoup(innerHTML, 'html.parser')
    owned_players = player_df.loc[player_df['owner'] != 'FA']
    drafted_players = owned_players.loc[pd.isnull(owned_players['keeper_val'])]
    for ind, player in drafted_players.iterrows():
        draft_row = html(text=player['name'])[0].find_parents('tr')[0]
        round_header = draft_row.find_previous_siblings('tr')[-1].get_text()
        player_df.loc[ind]['keeper_val'] = int(re.split(' ', round_header)[-1])
        if prev_player_df:
            kept_twice = not pd.isnull(prev_player_df.loc[
                prev_player_df['name']==player['name']]['keeper_val'][0])
            if (player_df.loc[ind]['keeper_val']>1) & kept_twice:
                player_df.loc[ind]['keeper_val'] -= 1

    return(player_df)

# %%
for ind, player in player_df2.iterrows():
    if np.isnan(player['keeper_val']):
        player['keeper_val'] = -1

# %%
# Out:
# True

# %%
player_df = holder.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4118295fd849> in <module>()
# ----> 1 player_df = holder.copy()
#
# NameError: name 'holder' is not defined

# %%
driver = espn_login()

# %%
player_df = update_player_df(driver=driver)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-baff13fce805> in <module>()
# ----> 1 player_df = update_player_df(driver=driver)
#
# <ipython-input-3-3117c6c346c9> in update_player_df(driver)
#      35             html = BeautifulSoup(innerHTML, 'html.parser')
#      36             player_table = html.find(id='playertable_0')
# ---> 37             last_player_loaded = player_table.find_all('tr')[-1]
#      38             last_player_loaded = last_player_loaded.find_all('td')[0].get_text()
#      39             if last_player_logged != last_player_loaded:
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
player_df2 = update_keeper_val(driver=driver, prev_player_df=None, player_df=player_df)
# Out:
#      keeper_val                    name owner   pos     team
# 0           NaN          Russell Wilson  KERS    QB      Sea
# 1           NaN          Todd Gurley II  BELL    RB      LAR
# 2           NaN              Cam Newton  BELL    QB      Car
# 3           NaN               Tom Brady  2xDC    QB       NE
# 4             7              Alex Smith  2xDC    QB      Wsh
# 5           NaN            Carson Wentz  HUFF    QB      Phi
# 6           NaN            Kirk Cousins  HUFF    QB      Min
# 7           NaN        Matthew Stafford   DEC    QB      Det
# 8             7           Philip Rivers  MAGA    QB      LAC
# 9           NaN              Drew Brees  KYPE    QB       NO
# 10            7      Ben Roethlisberger   DIX    QB      Pit
# 11          NaN            Dak Prescott  KCMO    QB      Dal
# 12          NaN            Le'Veon Bell  BELL    RB      Pit
# 13            7              Jared Goff  IRAN    QB      LAR
# 14          NaN           Blake Bortles    FA    QB      Jax
# 15          NaN             Kareem Hunt  MAGA    RB       KC
# 16            7            Alvin Kamara   DIX    RB       NO
# 17            7             Case Keenum  KCMO    QB      Den
# 18          NaN           Melvin Gordon   DIX    RB      LAC
# 19            7               Matt Ryan  BELL    QB      Atl
# 20          NaN            Tyrod Taylor    FA    QB      Cle
# 21          NaN             Mark Ingram  IRAN    RB       NO
# 22          NaN         DeAndre Hopkins  BELL    WR      Hou
# 23          NaN             Andy Dalton    FA    QB      Cin
# 24          NaN          Marcus Mariota   DIX    QB      Ten
# 25          NaN           Antonio Brown   DEC    WR      Pit
# 26          NaN            Jaguars D/ST  KERS  D/ST  Jaguars
# 27          NaN              Derek Carr  IRAN    QB      Oak
# 28          NaN         Jacoby Brissett    FA    QB      Ind
# 29          NaN             Josh McCown    FA    QB      NYJ
# ...         ...                     ...   ...   ...      ...
# 1052        NaN            Jahad Thomas    FA    RB      NYJ
# 1053        NaN  Damore'ea Stringfellow    FA    WR      NYJ
# 1054        NaN          Taquan Mizzell    FA    RB      Chi
# 1055        NaN             Taysom Hill    FA    QB       NO
# 1056        NaN       Victor Bolden Jr.    FA    WR       SF
# 1057        NaN             Sean Culkin    FA    TE      LAC
# 1058        NaN           Cethan Carter    FA    TE      Cin
# 1059        NaN             Evan Baylis    FA    TE      Car
# 1060        NaN             Shane Smith    FA    TE      NYG
# 1061        NaN          Krishawn Hogan    FA    WR      Ind
# 1062        NaN     Henry Krieger-Coble    FA    TE      LAR
# 1063        NaN                Ed Eagan    FA    WR      NYG
# 1064        NaN         Carlton Agudosi    FA    WR      Ari
# 1065        NaN           Isaac Whitney    FA    WR      Oak
# 1066        NaN            Austin Davis    FA    QB      Sea
# 1067        NaN         Darren McFadden    FA    RB      Dal
# 1068        NaN            Chase Daniel    FA    QB      Chi
# 1069        NaN              Chad Henne    FA    QB       KC
# 1070        NaN         Isaiah McKenzie    FA    WR      Den
# 1071        NaN           Andre Roberts    FA    WR      NYJ
# 1072        NaN               John Ross    FA    WR      Cin
# 1073        NaN           Kalif Raymond    FA    WR      NYG
# 1074        NaN             Jake Rudock    FA    QB      Det
# 1075        NaN          Kellen Clemens    FA    QB      LAC
# 1076        NaN            Devante Mays    FA    RB       GB
# 1077        NaN              Tyler Bray    FA    QB      Chi
# 1078        NaN       Teddy Bridgewater    FA    QB      NYJ
# 1079        NaN          Preston Parker    FA    WR       FA
# 1080        NaN             Montee Ball    FA    RB       FA
# 1081        NaN           Joseph Randle    FA    RB       FA
#
# [1082 rows x 5 columns]

# %%
player_df2
# Out:
#      keeper_val                    name owner   pos     team
# 0             1          Russell Wilson  KERS    QB      Sea
# 1            -1          Todd Gurley II  BELL    RB      LAR
# 2            -1              Cam Newton  BELL    QB      Car
# 3             8               Tom Brady  2xDC    QB       NE
# 4             7              Alex Smith  2xDC    QB      Wsh
# 5            15            Carson Wentz  HUFF    QB      Phi
# 6             5            Kirk Cousins  HUFF    QB      Min
# 7             6        Matthew Stafford   DEC    QB      Det
# 8             7           Philip Rivers  MAGA    QB      LAC
# 9             4              Drew Brees  KYPE    QB       NO
# 10            7      Ben Roethlisberger   DIX    QB      Pit
# 11            9            Dak Prescott  KCMO    QB      Dal
# 12           -1            Le'Veon Bell  BELL    RB      Pit
# 13            7              Jared Goff  IRAN    QB      LAR
# 14           -1           Blake Bortles    FA    QB      Jax
# 15            3             Kareem Hunt  MAGA    RB       KC
# 16            7            Alvin Kamara   DIX    RB       NO
# 17            7             Case Keenum  KCMO    QB      Den
# 18            1           Melvin Gordon   DIX    RB      LAC
# 19            7               Matt Ryan  BELL    QB      Atl
# 20           -1            Tyrod Taylor    FA    QB      Cle
# 21            2             Mark Ingram  IRAN    RB       NO
# 22            5         DeAndre Hopkins  BELL    WR      Hou
# 23           -1             Andy Dalton    FA    QB      Cin
# 24            7          Marcus Mariota   DIX    QB      Ten
# 25            1           Antonio Brown   DEC    WR      Pit
# 26           12            Jaguars D/ST  KERS  D/ST  Jaguars
# 27           11              Derek Carr  IRAN    QB      Oak
# 28           -1         Jacoby Brissett    FA    QB      Ind
# 29           -1             Josh McCown    FA    QB      NYJ
# ...         ...                     ...   ...   ...      ...
# 1052         -1            Jahad Thomas    FA    RB      NYJ
# 1053         -1  Damore'ea Stringfellow    FA    WR      NYJ
# 1054         -1          Taquan Mizzell    FA    RB      Chi
# 1055         -1             Taysom Hill    FA    QB       NO
# 1056         -1       Victor Bolden Jr.    FA    WR       SF
# 1057         -1             Sean Culkin    FA    TE      LAC
# 1058         -1           Cethan Carter    FA    TE      Cin
# 1059         -1             Evan Baylis    FA    TE      Car
# 1060         -1             Shane Smith    FA    TE      NYG
# 1061         -1          Krishawn Hogan    FA    WR      Ind
# 1062         -1     Henry Krieger-Coble    FA    TE      LAR
# 1063         -1                Ed Eagan    FA    WR      NYG
# 1064         -1         Carlton Agudosi    FA    WR      Ari
# 1065         -1           Isaac Whitney    FA    WR      Oak
# 1066         -1            Austin Davis    FA    QB      Sea
# 1067         -1         Darren McFadden    FA    RB      Dal
# 1068         -1            Chase Daniel    FA    QB      Chi
# 1069         -1              Chad Henne    FA    QB       KC
# 1070         -1         Isaiah McKenzie    FA    WR      Den
# 1071         -1           Andre Roberts    FA    WR      NYJ
# 1072         -1               John Ross    FA    WR      Cin
# 1073         -1           Kalif Raymond    FA    WR      NYG
# 1074         -1             Jake Rudock    FA    QB      Det
# 1075         -1          Kellen Clemens    FA    QB      LAC
# 1076         -1            Devante Mays    FA    RB       GB
# 1077         -1              Tyler Bray    FA    QB      Chi
# 1078         -1       Teddy Bridgewater    FA    QB      NYJ
# 1079         -1          Preston Parker    FA    WR       FA
# 1080         -1             Montee Ball    FA    RB       FA
# 1081         -1           Joseph Randle    FA    RB       FA
#
# [1082 rows x 5 columns]

# %%
idx = player_df2.loc[player_df2['name'] == "Matt Ryan"].index[0]
# idx = 3;
print(idx)
player_df2.loc[idx]['keeper_val'] = 7#player_df.loc[idx]['keeper_val'] - 1
player_df2.ix[idx]
# Out:
# 19
# keeper_val            7
# name          Matt Ryan
# owner              BELL
# pos                  QB
# team                Atl
# Name: 19, dtype: object

# %%
engine = create_engine('sqlite://', echo=False)

# %%
conn = sqlite3.connect("draft_website\db.sqlite3")
cursor = conn.cursor()

# %%
player_df.to_sql('player_table', conn, if_exists="replace")

# %%
sql_command = """INSERT INTO draft_client_team (id, team_name)
    VALUES (11, "FA");"""
cursor.execute(sql_command)
conn.commit()
conn.close()

# %%
# Out:
# 1082

# %%
pick_sequence = np.array([9, 5, 6, 1, 8, 4, 7, 3, 2, 10])
for pick in range(22):
    rnd = 1 + pick//10
    pick_in_round = 1 + pick%10
    owner_id = pick_sequence[pick_in_round - 1]
    sql_command = "INSERT INTO draft_client_draft (id, rnd, pick, owner_id," \
        "selection_id) VALUES ({}, {}, {}, {}, {});".format(pick, rnd, pick_in_round, owner_id, 1)
    cursor.execute(sql_command)
conn.commit()
conn.close()

# %%
conn = sqlite3.connect("draft_website\db.sqlite3")
cursor = conn.cursor()
for idx, player in player_df.iterrows():
    player_id = idx+2
    name = player_df2.loc[idx]['name']
    pos = player_df2.loc[idx]['pos']
    team = player_df2.loc[idx]['team']
    keeper_val = player_df2.loc[idx]['keeper_val']
    format_str = """INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id) 
        VALUES ({}, "{}", "{}", "{}", {}, {});"""
    sql_command = format_str.format(player_id, name, pos, team, keeper_val, 11)
    print(sql_command)
    cursor.execute(sql_command)
conn.commit()
conn.close()
# Out:
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (2, "Russell Wilson", "QB", "Sea", 1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (3, "Todd Gurley II", "RB", "LAR", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (4, "Cam Newton", "QB", "Car", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (5, "Tom Brady", "QB", "NE", 8, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (6, "Alex Smith", "QB", "Wsh", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (7, "Carson Wentz", "QB", "Phi", 15, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (8, "Kirk Cousins", "QB", "Min", 5, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (9, "Matthew Stafford", "QB", "Det", 6, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (10, "Philip Rivers", "QB", "LAC", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (11, "Drew Brees", "QB", "NO", 4, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (12, "Ben Roethlisberger", "QB", "Pit", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (13, "Dak Prescott", "QB", "Dal", 9, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (14, "Le'Veon Bell", "RB", "Pit", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (15, "Jared Goff", "QB", "LAR", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (16, "Blake Bortles", "QB", "Jax", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (17, "Kareem Hunt", "RB", "KC", 3, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (18, "Alvin Kamara", "RB", "NO", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (19, "Case Keenum", "QB", "Den", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (20, "Melvin Gordon", "RB", "LAC", 1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (21, "Matt Ryan", "QB", "Atl", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (22, "Tyrod Taylor", "QB", "Cle", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (23, "Mark Ingram", "RB", "NO", 2, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (24, "DeAndre Hopkins", "WR", "Hou", 5, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (25, "Andy Dalton", "QB", "Cin", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (26, "Marcus Mariota", "QB", "Ten", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (27, "Antonio Brown", "WR", "Pit", 1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (28, "Jaguars D/ST", "D/ST", "Jaguars", 12, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (29, "Derek Carr", "QB", "Oak", 11, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (30, "Jacoby Brissett", "QB", "Ind", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (31, "Josh McCown", "QB", "NYJ", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (32, "LeSean McCoy", "RB", "Buf", 1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (33, "Jameis Winston", "QB", "TB", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (34, "Leonard Fournette", "RB", "Jax", 2, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (35, "Eli Manning", "QB", "NYG", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (36, "Joe Flacco", "QB", "Bal", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (37, "Keenan Allen", "WR", "LAC", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (38, "Greg Zuerlein", "K", "LAR", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (39, "Ezekiel Elliott", "RB", "Dal", 1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (40, "Jordan Howard", "RB", "Chi", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (41, "DeShone Kizer", "QB", "GB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (42, "Carlos Hyde", "RB", "Cle", 3, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (43, "Ravens D/ST", "D/ST", "Ravens", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (44, "Dion Lewis", "RB", "Ten", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (45, "Tyreek Hill", "WR", "KC", 6, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (46, "Stephen Gostkowski", "K", "NE", 12, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (47, "Deshaun Watson", "QB", "Hou", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (48, "Robbie Gould", "K", "SF", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (49, "Devonta Freeman", "RB", "Atl", 6, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (50, "Marvin Jones Jr.", "WR", "Det", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (51, "Julio Jones", "WR", "Atl", 1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (52, "Justin Tucker", "K", "Bal", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (53, "Eagles D/ST", "D/ST", "Eagles", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (54, "Rob Gronkowski", "TE", "NE", 1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (55, "Jay Cutler", "QB", "Mia", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (56, "Lamar Miller", "RB", "Hou", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (57, "Matt Bryant", "K", "Atl", 13, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (58, "Wil Lutz", "K", "NO", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (59, "Brandin Cooks", "WR", "LAR", 3, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (60, "Chris Boswell", "K", "Pit", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (61, "Harrison Butker", "K", "KC", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (62, "Michael Thomas", "WR", "NO", 14, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (63, "Rams D/ST", "D/ST", "Rams", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (64, "Larry Fitzgerald", "WR", "Ari", 4, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (65, "A.J. Green", "WR", "Cin", 2, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (66, "Travis Kelce", "TE", "KC", 6, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (67, "Ryan Succop", "K", "Ten", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (68, "Adam Thielen", "WR", "Min", 9, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (69, "Christian McCaffrey", "RB", "Car", 3, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (70, "Davante Adams", "WR", "GB", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (71, "Doug Baldwin", "WR", "Sea", 2, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (72, "Jarvis Landry", "WR", "Cle", 3, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (73, "Alex Collins", "RB", "Bal", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (74, "C.J. Anderson", "RB", "Den", 5, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (75, "Matt Prater", "K", "Det", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (76, "Chargers D/ST", "D/ST", "Chargers", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (77, "Frank Gore", "RB", "Mia", 5, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (78, "Marshawn Lynch", "RB", "Oak", 3, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (79, "Lions D/ST", "D/ST", "Lions", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (80, "Latavius Murray", "RB", "Min", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (81, "Duke Johnson Jr.", "RB", "Cle", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (82, "Kai Forbath", "K", "Min", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (83, "Tevin Coleman", "RB", "Atl", 11, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (84, "JuJu Smith-Schuster", "WR", "Pit", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (85, "Alshon Jeffery", "WR", "Phi", 2, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (86, "Robby Anderson", "WR", "NYJ", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (87, "Bears D/ST", "D/ST", "Bears", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (88, "Steelers D/ST", "D/ST", "Steelers", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (89, "Seahawks D/ST", "D/ST", "Seahawks", 9, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (90, "Mitchell Trubisky", "QB", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (91, "Stefon Diggs", "WR", "Min", 5, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (92, "Jake Elliott", "K", "Phi", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (93, "Stephen Hauschka", "K", "Buf", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (94, "Golden Tate", "WR", "Det", 4, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (95, "DeMarco Murray", "RB", "Ten", 4, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (96, "Mike Evans", "WR", "TB", 2, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (97, "Devin Funchess", "WR", "Car", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (98, "Nelson Agholor", "WR", "Phi", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (99, "Graham Gano", "K", "Car", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (100, "Saints D/ST", "D/ST", "Saints", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (101, "Aaron Rodgers", "QB", "GB", 1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (102, "Phil Dawson", "K", "Ari", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (103, "Zach Ertz", "TE", "Phi", 9, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (104, "Vikings D/ST", "D/ST", "Vikings", 12, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (105, "Jerick McKinnon", "RB", "SF", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (106, "Trevor Siemian", "QB", "Min", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (107, "Panthers D/ST", "D/ST", "Panthers", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (108, "Derrick Henry", "RB", "Ten", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (109, "Brett Hundley", "QB", "GB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (110, "Demaryius Thomas", "WR", "Den", 3, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (111, "Bilal Powell", "RB", "NYJ", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (112, "Javorius Allen", "RB", "Bal", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (113, "Adam Vinatieri", "K", "Ind", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (114, "Orleans Darkwa", "RB", "NYG", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (115, "T.Y. Hilton", "WR", "Ind", 3, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (116, "Jamaal Williams", "RB", "GB", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (117, "Dez Bryant", "WR", "Dal", 2, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (118, "Broncos D/ST", "D/ST", "Broncos", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (119, "Kenny Stills", "WR", "Mia", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (120, "Isaiah Crowell", "RB", "NYJ", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (121, "Chandler Catanzaro", "K", "TB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (122, "Cooper Kupp", "WR", "LAR", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (123, "Jimmy Graham", "TE", "GB", 5, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (124, "Michael Crabtree", "WR", "Bal", 8, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (125, "Marquise Goodwin", "WR", "SF", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (126, "Chris Thompson", "RB", "Wsh", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (127, "Joe Mixon", "RB", "Cin", 4, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (128, "Jay Ajayi", "RB", "Phi", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (129, "Jermaine Kearse", "WR", "NYJ", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (130, "Amari Cooper", "WR", "Oak", 1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (131, "Kenyan Drake", "RB", "Mia", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (132, "Evan Engram", "TE", "NYG", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (133, "Jonathan Stewart", "RB", "NYG", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (134, "Giovani Bernard", "RB", "Cin", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (135, "Cowboys D/ST", "D/ST", "Cowboys", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (136, "Mohamed Sanu", "WR", "Atl", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (137, "Robert Woods", "WR", "LAR", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (138, "Sammy Watkins", "WR", "KC", 6, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (139, "Ted Ginn Jr.", "WR", "NO", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (140, "Paul Richardson", "WR", "Wsh", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (141, "Cardinals D/ST", "D/ST", "Cardinals", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (142, "Rishard Matthews", "WR", "Ten", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (143, "Carson Palmer", "QB", "Ari", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (144, "Kyle Rudolph", "TE", "Min", 8, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (145, "Theo Riddick", "RB", "Det", 9, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (146, "Brandon McManus", "K", "Den", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (147, "Titans D/ST", "D/ST", "Titans", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (148, "Chiefs D/ST", "D/ST", "Chiefs", 13, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (149, "Delanie Walker", "TE", "Ten", 6, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (150, "Blair Walsh", "K", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (151, "Rex Burkhead", "RB", "NE", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (152, "LeGarrette Blount", "RB", "Det", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (153, "Ameer Abdullah", "RB", "Det", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (154, "Mike Wallace", "WR", "Phi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (155, "Ka'imi Fairbairn", "K", "Hou", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (156, "Tarik Cohen", "RB", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (157, "Travis Benjamin", "WR", "LAC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (158, "Cameron Brate", "TE", "TB", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (159, "Cody Parkey", "K", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (160, "Falcons D/ST", "D/ST", "Falcons", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (161, "Patriots D/ST", "D/ST", "Patriots", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (162, "Tyrell Williams", "WR", "LAC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (163, "Jamison Crowder", "WR", "Wsh", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (164, "Redskins D/ST", "D/ST", "Redskins", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (165, "Randall Cobb", "WR", "GB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (166, "Marqise Lee", "WR", "Jax", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (167, "Keelan Cole", "WR", "Jax", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (168, "Randy Bullock", "K", "Cin", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (169, "Jack Doyle", "TE", "Ind", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (170, "C.J. Beathard", "QB", "SF", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (171, "DeSean Jackson", "WR", "TB", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (172, "Bengals D/ST", "D/ST", "Bengals", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (173, "Kelvin Benjamin", "WR", "Buf", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (174, "Jimmy Garoppolo", "QB", "SF", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (175, "Samaje Perine", "RB", "Wsh", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (176, "Josh Lambo", "K", "Jax", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (177, "Bills D/ST", "D/ST", "Bills", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (178, "Sterling Shepard", "WR", "NYG", 10, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (179, "Will Fuller V", "WR", "Hou", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (180, "Giorgio Tavecchio", "K", "Oak", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (181, "Josh Doctson", "WR", "Wsh", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (182, "Jordy Nelson", "WR", "Oak", 6, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (183, "Jason Witten", "TE", "Dal", 8, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (184, "Matt Forte", "RB", "NYJ", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (185, "Dolphins D/ST", "D/ST", "Dolphins", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (186, "Martavis Bryant", "WR", "Pit", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (187, "Matt Breida", "RB", "SF", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (188, "Tyler Kroft", "TE", "Cin", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (189, "Corey Clement", "RB", "Phi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (190, "Marlon Mack", "RB", "Ind", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (191, "Patrick Murray", "K", "TB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (192, "Hunter Henry", "TE", "LAC", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (193, "Ryan Grant", "WR", "Ind", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (194, "Mason Crosby", "K", "GB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (195, "Austin Ekeler", "RB", "LAC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (196, "Eric Ebron", "TE", "Ind", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (197, "Tyler Lockett", "WR", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (198, "Buccaneers D/ST", "D/ST", "Buccaneers", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (199, "Vernon Davis", "TE", "Wsh", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (200, "Jared Cook", "TE", "Oak", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (201, "James White", "RB", "NE", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (202, "Danny Amendola", "WR", "Mia", 16, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (203, "Aldrick Rosas", "K", "NYG", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (204, "Benjamin Watson", "TE", "NO", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (205, "Dan Bailey", "K", "Dal", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (206, "Packers D/ST", "D/ST", "Packers", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (207, "Chris Hogan", "WR", "NE", 12, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (208, "O.J. Howard", "TE", "TB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (209, "Texans D/ST", "D/ST", "Texans", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (210, "Albert Wilson", "WR", "Mia", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (211, "Browns D/ST", "D/ST", "Browns", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (212, "Ryan Fitzpatrick", "QB", "TB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (213, "Rod Smith", "RB", "Dal", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (214, "DeVante Parker", "WR", "Mia", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (215, "Zane Gonzalez", "K", "Cle", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (216, "Brandon LaFell", "WR", "Cin", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (217, "Jaron Brown", "WR", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (218, "Aaron Jones", "RB", "GB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (219, "Wayne Gallman", "RB", "NYG", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (220, "Austin Hooper", "TE", "Atl", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (221, "Peyton Barber", "RB", "TB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (222, "Ty Montgomery", "RB", "GB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (223, "Brock Osweiler", "QB", "Mia", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (224, "Adrian Peterson", "RB", "Ari", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (225, "Charles Clay", "TE", "Buf", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (226, "Mike Gillislee", "RB", "NE", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (227, "Adam Humphries", "WR", "TB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (228, "Emmanuel Sanders", "WR", "Den", 4, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (229, "Kendall Wright", "WR", "Min", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (230, "Doug Martin", "RB", "Oak", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (231, "Deonte Thompson", "WR", "Dal", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (232, "Kenny Golladay", "WR", "Det", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (233, "Alfred Morris", "RB", "Dal", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (234, "J.J. Nelson", "WR", "Ari", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (235, "Brian Hoyer", "QB", "NE", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (236, "Marcedes Lewis", "TE", "Jax", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (237, "Chris Ivory", "RB", "Buf", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (238, "George Kittle", "TE", "SF", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (239, "J.D. McKissic", "RB", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (240, "Colts D/ST", "D/ST", "Colts", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (241, "David Njoku", "TE", "Cle", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (242, "Eric Decker", "WR", "Ten", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (243, "Jeremy Maclin", "WR", "Bal", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (244, "Blaine Gabbert", "QB", "Ten", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (245, "Devontae Booker", "RB", "Den", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (246, "Dustin Hopkins", "K", "Wsh", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (247, "49ers D/ST", "D/ST", "49ers", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (248, "Allen Hurns", "WR", "Dal", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (249, "Elijah McGuire", "RB", "NYJ", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (250, "Jalen Richard", "RB", "Oak", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (251, "Giants D/ST", "D/ST", "Giants", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (252, "Chris Godwin", "WR", "TB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (253, "Terrance Williams", "WR", "Dal", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (254, "Kerwynn Williams", "RB", "Ari", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (255, "T.J. Yeldon", "RB", "Jax", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (256, "Garrett Celek", "TE", "SF", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (257, "Julius Thomas", "TE", "Mia", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (258, "Trey Burton", "TE", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (259, "Nick Rose", "K", "LAC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (260, "Jets D/ST", "D/ST", "Jets", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (261, "Cole Beasley", "WR", "Dal", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (262, "Jesse James", "TE", "Pit", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (263, "Cordarrelle Patterson", "WR", "NE", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (264, "Raiders D/ST", "D/ST", "Raiders", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (265, "Torrey Smith", "WR", "Car", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (266, "Dalvin Cook", "RB", "Min", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (267, "Roger Lewis", "WR", "NYG", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (268, "Bennie Fowler III", "WR", "Den", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (269, "Trent Taylor", "WR", "SF", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (270, "Mike Nugent", "K", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (271, "Connor Barth", "K", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (272, "Austin Seferian-Jenkins", "TE", "Jax", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (273, "TJ Jones", "WR", "Det", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (274, "Donte Moncrief", "WR", "Jax", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (275, "DeAndre Washington", "RB", "Oak", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (276, "D'Onta Foreman", "RB", "Hou", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (277, "Tom Savage", "QB", "Hou", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (278, "Drew Stanton", "QB", "Cle", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (279, "Brandon Coleman", "WR", "NO", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (280, "Pierre Garcon", "WR", "SF", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (281, "Ed Dickson", "TE", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (282, "Brice Butler", "WR", "Ari", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (283, "Antonio Gates", "TE", "LAC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (284, "Odell Beckham Jr.", "WR", "NYG", 1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (285, "Jason Myers", "K", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (286, "John Brown", "WR", "Bal", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (287, "Taylor Gabriel", "WR", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (288, "Andre Ellington", "RB", "Hou", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (289, "Chris Moore", "WR", "Bal", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (290, "Seth Roberts", "WR", "Oak", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (291, "Bruce Ellington", "WR", "Hou", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (292, "Charcandrick West", "RB", "KC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (293, "Jamaal Charles", "RB", "Den", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (294, "Jermaine Gresham", "TE", "Ari", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (295, "Joshua Bellamy", "WR", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (296, "Zay Jones", "WR", "Buf", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (297, "Seth DeValve", "TE", "Cle", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (298, "Cody Latimer", "WR", "NYG", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (299, "Corey Coleman", "WR", "Cle", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (300, "Tavarres King", "WR", "Min", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (301, "Nick O'Leary", "TE", "Buf", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (302, "Nick Novak", "K", "LAC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (303, "Malcolm Brown", "RB", "LAR", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (304, "Rashard Higgins", "WR", "Cle", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (305, "Coby Fleener", "TE", "NO", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (306, "Matt Moore", "QB", "Mia", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (307, "Dontrelle Inman", "WR", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (308, "Stephen Anderson", "TE", "Hou", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (309, "Justin Hardy", "WR", "Atl", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (310, "Dede Westbrook", "WR", "Jax", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (311, "Shane Vereen", "RB", "NYG", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (312, "Damien Williams", "RB", "KC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (313, "Josh Gordon", "WR", "Cle", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (314, "Luke Willson", "TE", "Det", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (315, "Rob Kelley", "RB", "Wsh", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (316, "Corey Grant", "RB", "Jax", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (317, "Charles Sims", "RB", "TB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (318, "Ricky Seals-Jones", "TE", "Ari", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (319, "Aldrick Robinson", "WR", "SF", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (320, "Jacquizz Rodgers", "RB", "TB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (321, "Kenny Britt", "WR", "NE", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (322, "Alfred Blue", "RB", "Hou", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (323, "Mike Davis", "RB", "Sea", 7, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (324, "Benny Cunningham", "RB", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (325, "Kyle Juszczyk", "RB", "SF", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (326, "Mike Tolbert", "RB", "Buf", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (327, "Johnny Holton", "WR", "Oak", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (328, "Darren Fells", "TE", "Cle", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (329, "Ricardo Louis", "WR", "Cle", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (330, "Gerald Everett", "TE", "LAR", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (331, "Zach Miller*", "TE", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (332, "Rhett Ellison", "TE", "NYG", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (333, "Tyler Higbee", "TE", "LAR", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (334, "Corey Davis", "WR", "Ten", 16, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (335, "Chester Rogers", "WR", "Ind", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (336, "Tyler Boyd", "WR", "Cin", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (337, "A.J. Derby", "TE", "Mia", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (338, "T.J. Yates", "QB", "Hou", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (339, "Nick Foles", "QB", "Phi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (340, "Kevin Hogan", "QB", "Wsh", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (341, "Mike Glennon", "QB", "Ari", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (342, "Wendell Smallwood", "RB", "Phi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (343, "Michael Campanaro", "WR", "Ten", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (344, "Taywan Taylor", "WR", "Ten", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (345, "Jordan Reed", "TE", "Wsh", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (346, "Chris Carson", "RB", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (347, "Jordan Matthews", "WR", "NE", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (348, "Jarius Wright", "WR", "Car", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (349, "Jakeem Grant", "WR", "Mia", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (350, "Adam Shaheen", "TE", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (351, "Andre Holmes", "WR", "Buf", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (352, "Terrelle Pryor Sr.", "WR", "NYJ", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (353, "Tion Green", "RB", "Det", -1, 11);
# ...
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (968, "Daniel Braverman", "WR", "KC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (969, "Thomas Duarte", "TE", "Mia", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (970, "Daniel Lasco", "RB", "NO", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (971, "Devin Lewis Fuller", "WR", "Atl", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (972, "Keith Marshall", "RB", "Wsh", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (973, "Kenny Lawler", "WR", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (974, "Zac Brooks", "RB", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (975, "Beau Sandland", "TE", "GB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (976, "Trevone Boykin", "QB", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (977, "Ben Braunecker", "TE", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (978, "Cole Wick", "TE", "SF", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (979, "Matt LaCosse", "TE", "Den", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (980, "Erik Swoope", "TE", "Ind", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (981, "Brandon Wilds", "RB", "Jax", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (982, "Jhurell Pressley", "RB", "Atl", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (983, "Anthony Denham", "TE", "Phi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (984, "Reggie Bell", "WR", "NO", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (985, "Jake Kumerow", "WR", "GB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (986, "George Atkinson III", "RB", "KC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (987, "James Wilder Jr.", "RB", "Buf", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (988, "Bryce Williams", "TE", "Ari", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (989, "Marquez North", "WR", "LAR", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (990, "Andy Jones", "WR", "Det", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (991, "Xavier Rush", "WR", "NO", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (992, "Dom Williams", "WR", "Phi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (993, "R.J. Harris", "WR", "NO", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (994, "Paul McRoberts", "WR", "LAR", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (995, "Wendall Williams", "WR", "Hou", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (996, "Anthony Dable", "WR", "Atl", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (997, "Darius Jennings", "WR", "Ten", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (998, "Devon Cajuste", "WR", "Cle", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (999, "Mitch Mathews", "WR", "Mia", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1000, "Stephen Morris", "QB", "Wsh", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1001, "Dreamius Smith", "RB", "LAC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1002, "Devon Johnson", "RB", "Car", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1003, "Keyarris Garrett", "WR", "Car", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1004, "Jalin Marshall", "WR", "NYJ", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1005, "Braedon Bowman", "TE", "LAC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1006, "Brian Parker", "TE", "Den", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1007, "Troymaine Pope", "RB", "Hou", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1008, "Glenn Gronkowski", "RB", "NE", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1009, "Julian Howsare", "RB", "NYJ", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1010, "Kenneth Farrow", "RB", "LAC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1011, "Nelson Spruce", "WR", "KC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1012, "Joshua Perkins", "TE", "Phi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1013, "Paul Lasike", "RB", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1014, "Scott Simonson", "TE", "Car", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1015, "Don Jackson", "RB", "GB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1016, "Paul Turner", "WR", "NO", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1017, "George Farmer", "RB", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1018, "D.J. Tialavea", "TE", "Atl", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1019, "Matt Lengel", "TE", "Cle", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1020, "Alex Ellis", "TE", "Jax", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1021, "Donnel Pumphrey", "RB", "Phi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1022, "Elijah Hood", "RB", "Oak", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1023, "Brad Kaaya", "QB", "Ind", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1024, "Chad Kelly", "QB", "Den", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1025, "Marquez Williams", "RB", "Cle", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1026, "Malachi Dupre", "WR", "Buf", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1027, "Rodney Adams", "WR", "Min", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1028, "Joshua Dobbs", "QB", "Pit", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1029, "Jordan Leggett", "TE", "NYJ", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1030, "Jake Butt", "TE", "Den", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1031, "Mason Schreck", "TE", "Cin", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1032, "David Moore", "WR", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1033, "T.J. Logan", "RB", "Ari", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1034, "Carlos Henderson", "WR", "Den", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1035, "Robert Davis", "WR", "Wsh", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1036, "Bucky Hodges", "TE", "Min", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1037, "Sam Rogers", "RB", "LAR", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1038, "Isaiah Ford", "WR", "Mia", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1039, "Eric Saubert", "TE", "Atl", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1040, "Joe Williams", "RB", "SF", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1041, "Stacy Coley", "WR", "Min", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1042, "Khalfani Muhammad", "RB", "Ten", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1043, "Jeremy McNichols", "RB", "SF", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1044, "DeAngelo Yancey", "WR", "GB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1045, "Davis Webb", "QB", "NYG", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1046, "Freddie Stevenson", "RB", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1047, "Jace Billingsley", "WR", "Det", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1048, "Ishmael Zamora", "WR", "Oak", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1049, "Austin Carr", "WR", "NO", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1050, "Hakeem Valles", "TE", "Det", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1051, "Rashawn Scott", "WR", "Mia", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1052, "Rannell Hall", "WR", "Cle", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1053, "Algernon Brown", "RB", "NYJ", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1054, "Jahad Thomas", "RB", "NYJ", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1055, "Damore'ea Stringfellow", "WR", "NYJ", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1056, "Taquan Mizzell", "RB", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1057, "Taysom Hill", "QB", "NO", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1058, "Victor Bolden Jr.", "WR", "SF", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1059, "Sean Culkin", "TE", "LAC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1060, "Cethan Carter", "TE", "Cin", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1061, "Evan Baylis", "TE", "Car", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1062, "Shane Smith", "TE", "NYG", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1063, "Krishawn Hogan", "WR", "Ind", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1064, "Henry Krieger-Coble", "TE", "LAR", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1065, "Ed Eagan", "WR", "NYG", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1066, "Carlton Agudosi", "WR", "Ari", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1067, "Isaac Whitney", "WR", "Oak", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1068, "Austin Davis", "QB", "Sea", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1069, "Darren McFadden", "RB", "Dal", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1070, "Chase Daniel", "QB", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1071, "Chad Henne", "QB", "KC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1072, "Isaiah McKenzie", "WR", "Den", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1073, "Andre Roberts", "WR", "NYJ", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1074, "John Ross", "WR", "Cin", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1075, "Kalif Raymond", "WR", "NYG", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1076, "Jake Rudock", "QB", "Det", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1077, "Kellen Clemens", "QB", "LAC", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1078, "Devante Mays", "RB", "GB", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1079, "Tyler Bray", "QB", "Chi", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1080, "Teddy Bridgewater", "QB", "NYJ", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1081, "Preston Parker", "WR", "FA", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1082, "Montee Ball", "RB", "FA", -1, 11);
# INSERT INTO draft_client_player (id, name, pos, team, keeper_val, owner_id)
#         VALUES (1083, "Joseph Randle", "RB", "FA", -1, 11);

# %%
t = ['tanner']
"{t[0]}"
# Out:
# '{t[0]}'

# %%
# Out:
# 'tanner'
